# %%
# Montagem do drive do Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/drive/MyDrive/IFSP/2026-2/BRAADAD/Aula2/projeto_01.py
# Out:
# --- RESULTADOS DAS PREDIÇÕES: PROJETO 1 ---
# Target Estudado: 'diagnostico' (0: Estável, 1: Risco)
#
# Paciente 1: {'idade': 45, 'pressao': 128.0, 'eletro': 'Normal', 'fumante': 'Não'}
#    - Predição de diagnostico: 1
#    - Probabilidade Negativa (0): 49.91%
#    - Probabilidade Positiva (1): 50.09%
#
# Paciente 2: {'idade': 62, 'pressao': 150.0, 'eletro': 'Risco', 'fumante': 'Sim'}
#    - Predição de diagnostico: 0
#    - Probabilidade Negativa (0): 54.36%
#    - Probabilidade Positiva (1): 45.64%

# %%
df_treino, novos_dados = gerar_dados()
print("Tamanho do dataset principal: ", df_treino.shape)
df_treino.head()
# Out:
# Tamanho do dataset principal:  (1000, 5)
#    idade     pressao  eletro fumante  diagnostico
# 0     58  119.975461  Normal     Sim            0
# 1     71  113.609515   Risco     Não            1
# 2     48  139.131949   Risco     Sim            1
# 3     34  118.626509  Normal     Não            0
# 4     62  134.056088  Normal     Sim            0
